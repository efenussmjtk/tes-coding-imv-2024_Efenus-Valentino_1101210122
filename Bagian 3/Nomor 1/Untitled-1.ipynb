# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
img = cv2.imread('emma.jpg')
imgplot = plt.imshow(img)

# %%
img_flip_ud = cv2.flip(img, 0)
imgplot = plt.imshow(img_flip_ud)

# %%
img_flip_ud = cv2.flip(img, 1)
imgplot = plt.imshow(img_flip_ud)

# %%
transpose = Image.fromarray(np.flip(img, (0, 1))).save('emma_transpose.jpg')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 transpose = Image.fromarray(np.flip(img, (0, 1))).save('emma_transpose.jpg')
#
# NameError: name 'Image' is not defined
